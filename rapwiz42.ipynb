# %% [markdown]
# # rap wiz
#
# by: [pelgo14](https://github.com/pelgo14)
# reference: "Train a GPT-2 Text-Generating Model w/ GPU For Free" by [Max Woolf](http://minimaxir.com)
#
# read about this project in [**my blog post**](https://pelgo14.github.io/artificial-rapper)
#
# *Last updated: September 9th, 2020*
#
# features:
#
# * scrape lyrics from your favourite rappers
# * train gpt 2 on this dataset
# * generate (rhyming) rap lyrics
#
# To get started (in colab):
#
# 1. Copy this notebook to your Google Drive to keep it and save your changes. (File -> Save a Copy in Drive)
# 2. Make sure you're running the notebook with a GPU runtime.
# 3. Run the cells below, or use runtime/run-all
#
# To get started (local .ipynb)
#
# 0. install [miniconda](https://docs.conda.io/en/latest/miniconda.html)
#
# 1. create the conda environment with packages: jupyter, notebook, ...
#   - `conda env create -f environment.yml`
#
# 2. start jupyter notebook
#   - `jupyter notebook`
#
# 3. Run the cells below, or use runtime/run-all

# %%
# @markdown am i running in colab?
running_in_colab = True # @param {type:"boolean"}

# @markdown the artists to scrape lyrics from
# use "thrust" for debug, he has only 4 songs, else: "mf-doom", "aesop-rock", "aesop-rocky", etc...
artists = ["aesop-rock", "mf-doom", "asap-rocky", "kodak black"] #@param 

# @markdown your genius api key from https://genius.com/api-clients
key = "OSk3SqQp7_L1lqVhOBoCSNHz1Fy0J7UJQC2RLM4bhTVe7Ev5KeSzJUuZCq8HwrVJ" #@param {type:"string"}

# @markdown amount of steps to train
steps = 250 # @param {type:"number"}

# @markdown how many lines to generate
line_count = 4 # @param {type:"number"}


# @markdown the generated lines will appear here or at the bottom of the notebook
lines = [] # @param

# %% [markdown]
# **rapwiz42** is a neural network (gpt-2) and lyric corpus based lyric generation system.

# %% [markdown]
# ## setup

# %%
if running_in_colab:
  # !nvidia-smi
  # %tensorflow_version 1.x
# Out:
# Fri Sep 11 16:09:05 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8     8W /  75W |      0MiB /  7611MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# TensorFlow 1.x selected.

# %%
if running_in_colab:
  # !pip -q install pronouncing syllables progressbar2 gpt-2-simple enlighten lyricsgenius
# Out:
#      |████████████████████████████████| 51kB 5.0MB/s
#      |████████████████████████████████| 942kB 10.8MB/s
#      |████████████████████████████████| 81kB 7.8MB/s
#      |████████████████████████████████| 92kB 9.4MB/s
#   Building wheel for pronouncing (setup.py) ... done
#   Building wheel for gpt-2-simple (setup.py) ... done

# %%
import pronouncing
import syllables
import progressbar
import gpt_2_simple as gpt2

import logging

import urllib.request
import tarfile
import os

import random

import enlighten
import yaml
import lyricsgenius as genius
import fileinput
import json
import re
from os import listdir
from os.path import isfile, join

import concurrent.futures
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## classes

# %% [markdown]
# ### scraper class

# %%
class Scraper:
    def __init__(self, genius_key, bar):
        logging.basicConfig(level=logging.INFO)
        self.genius_key = genius_key
        self.bar = bar

    def scrape(self, artist):
        # scrape
        api = genius.Genius(self.genius_key)
        artist_api = api.search_artist(artist)
        try:
            artist_api.save_lyrics(overwrite=True)
        except:
            logging.warn(f"Oops! Cant download: {artist}")
        self.bar.update()
        return True

    def extract(self):
        """
        extract
        # "songs": [
        # {
        #  "lyrics": "verse..."
        #  } ,
        # ...
        # ]
        :return:
        """
        source_path = '.'
        source_files = [f for f in listdir(source_path) if isfile(join(source_path, f))]
        for file in source_files:
            if file.endswith('.json'):
                with open(file) as json_file:
                    data = json.load(json_file)
                    for p in data['songs']:
                        if p['lyrics']:
                            with open("lyricdb.txt", "ab") as myfile:
                                myfile.write(p['lyrics'].encode('ASCII', errors="ignore"))

    def clean_folder(self):
        dir_name = "."
        test = os.listdir(dir_name)
        for item in test:
            if item.endswith(".json"):
                os.remove(os.path.join(dir_name, item))

    def clean_lyricdb(self):
        # clean
        # [intro: eminem] <- needs to be removed
        # ...
        for line in fileinput.input(r"lyricdb.txt", inplace=True):
            if not re.search(r"([^\w\d\s',<?>])", line):
                print(line, end="")

    def scrape_list(self, artists):
        # https://stackoverflow.com/questions/6893968/how-to-get-the-return-value-from-a-thread-in-python
        # multi-threaded scraping with fault tolerance
        with concurrent.futures.ThreadPoolExecutor() as executor:
            tasks = {}
            for artist in artists:
                task = executor.submit(self.scrape, artist)
                tasks[artist] = task
            while len(tasks.keys()) != 0:
                for artist, task in tasks.copy().items():
                    try:
                        res = task.result()
                    except:
                        res = False
                    tasks.pop(artist)
                    if not res:
                        tasks[artist] = executor.submit(self.scrape, artist)

# %% [markdown]
# ### generator class

# %%
class Generator:
    def __init__(self, sess, log_level="INFO"):
        if "INFO" in log_level:
            logging.basicConfig(level=logging.INFO)
        elif "DEBUG" in log_level:
            logging.basicConfig(level=logging.DEBUG)
        self.sess = sess
        # gpt2.load_gpt2(self.sess, run_name="run1")

    def generate(self, line_count=16):
        """
        generates line_count amount of lines. every second line will rhyme with the previous
        (the last word of every second line will rhyme with the last word of the previous line)
        maybe_todo: add rhyme scheme support (not just ababab...)
        :param line_count:
        :return:
        """
        logging.info("generating lines...")
        lines = [self.gen_next_non_rhyme_line()]
        for i in progressbar.progressbar(range(1, line_count)):
            last_line = lines[i - 1]
            logging.debug(f"gen line num: {i}, last_line: {last_line}")
            logging.debug(f"lines: {lines}")
            if i % 2 == 1:
                line = self.gen_next_rhyme_line(last_line)
            else:
                line = self.gen_next_non_rhyme_line()
            lines.append(line)
        logging.info("generating lines... done!")
        for line in lines:
            print(line)
        return lines

    def gen_next_non_rhyme_line(self):
        """
        returns a line that suffices the is_good metric
        :return:
        """
        good_lines = []
        tries_per_iteration = 100
        i = 0
        while len(good_lines) == 0:
            logging.debug(f"trying to generate line. try:{i}")
            i += 1
            temp_lines = gpt2.generate(
                self.sess,
                return_as_list=True,
                length=12,
                temperature=0.8,
                nsamples=tries_per_iteration,
                batch_size=tries_per_iteration
            )
            temp_lines = [x.strip() for x in temp_lines]
            for line in temp_lines:
                if self.is_good(line):
                    good_lines.append(line)
        return random.choice(good_lines)

    def gen_next_rhyme_line(self, last_line):
        """
        returns a line that suffices the is_good metric and rhymes with last_line
        :param last_line:
        :return:
        """
        good_lines = []
        tries_per_iteration = 100
        i = 0
        while len(good_lines) == 0:
            logging.debug(f"try:{i} to generate rhyming line on line: {last_line}.")
            i += 1
            temp_lines = gpt2.generate(
                self.sess,
                return_as_list=True,
                length=12,
                temperature=0.8,
                nsamples=tries_per_iteration,
                batch_size=tries_per_iteration
            )
            temp_lines = [x.strip() for x in temp_lines]
            last_word = last_line.split()[-1]
            for line in temp_lines:
                this_last_word = line.split()[-1]
                if self.is_good(line) and self.rhymes(last_word, this_last_word):
                    good_lines.append(line)
            if i >= 30:
                return "Failed, next try"
        return random.choice(good_lines)


    def is_good(self, line):
        """"
        # defines a minimal metric for a "good" line
        # if line is empty or doesn't exist -> not good
        # if line is too short or too long -> not good
        # if there are (almost) no rhyme for the last word -> not good
        # if line is a multi-line line -> not good
        # if the line passed all checks it is good
        :param line:
        :return:
        """
        # if line is empty or doesn't exist -> not good
        if not line or len(line) == 0:
            return False

        # if line is too short or too long -> not good
        syl_count = syllables.estimate(line)
        if not 7 < syl_count < 18:
            return False

        # if there are (almost) no rhyme for the last word -> not good
        last_word = line.split()[-1]
        rhyme_list = pronouncing.rhymes(last_word)
        if not len(rhyme_list) > 20:
            return False

        # if line is a multi-line line -> not good
        if len(line.split("\n")) != 1:
            return False

        # if the line passed all checks it is good
        return True

    def rhymes(self, last_word, this_last_word):
        """ 
        :param last_word:
        :param this_last_word:
        :return: true if last_word rhymes with this_last_word
        """
        return this_last_word in pronouncing.rhymes(last_word)

# %% [markdown]
# ## main

# %% [markdown]
# ### scrape
#
# first, given a list of names of artists, their lyrics are scraped from genius.com.
#
#
# then a text corpus is created from the scraped lyrics, and the corpus is cleaned of any bad characters.

# %%
print("scraping...")
manager = enlighten.get_manager()
scrape_bar = manager.counter(total=len(artists), desc='scrape', unit='artists')
scraper = Scraper(key, scrape_bar)
scraper.scrape_list(artists)
scraper.extract()
scraper.clean_folder()
scraper.clean_lyricdb()
# Out:
# scraping...
# Searching for songs by aesop-rock...
#
# Searching for songs by mf-doom...
#
# Searching for songs by asap-rocky...
#
# Searching for songs by kodak black...
#
# Changing artist name to 'Aesop Rock'
# Changing artist name to 'A$AP Rocky'
# Changing artist name to 'MF DOOM'
# Changing artist name to 'Kodak Black'
# Song 1: "None Shall Pass"
# Song 1: "Fuckin’ Problems"
# Song 2: "Daylight"
# Song 1: "Doomsday"
# Song 3: "Zero Dark Thirty"
# Song 1: "Tunnel Vision"
# Song 4: "Rings"
# Song 2: "1Train"
# Song 2: "Beef Rapp"
# Song 5: "Coffee"
# Song 2: "No Flockin"
# Song 3: "Goldie"
# Song 3: "Roll in Peace"
# Song 6: "Gopher Guts"
# Song 4: "ZEZE"
# Song 7: "Kirby"
# Song 4: "Wild for the Night"
# Song 5: "Praise the Lord (Da Shine)"
# Song 5: "SKRT"
# Song 6: "Peso"
# Song 3: "That’s That"
# Song 7: "Everyday"
# Song 4: "Rapp Snitch Knishes"
# Song 8: "Long Live A$AP"
# Song 5: "Deep Fried Frenz"
# Song 9: "Fashion Killa"
# Song 8: "Dorks"
# Song 6: "Hoe Cakes"
# Song 6: "There He Go"
# Song 7: "One Beer"
# Song 9: "Mystery Fish"
# Song 7: "Skrilla"
# Song 10: "L$D"
# Song 8: "Codeine Dreaming"
# Song 10: "Shrunk"
# Song 9: "Transportin’"
# Song 8: "Rhymes Like Dimes"
# Song 11: "Blood Sandwich"
# Song 10: "Too Many Years"
# Song 12: "Get Out of the Car"
# Song 11: "Like Dat"
# Song 13: "Cycles to Gehenna"
# Song 11: "Lord Pretty Flacko Jodye 2 (LPFJ2)"
# Song 12: "Calling My Spirit"
# Song 14: "ZZZ Top"
# Song 15: "No Regrets"
# Song 12: "Multiply"
# Song 13: "I.M.Y (I Miss You)"
# Song 16: "9-5'ers Anthem"
# Song 17: "Leisureforce"
# Song 14: "Baby Girl"
# Song 15: "Institution"
# Song 18: "Night Light"
# Song 9: "Potholderz"
# Song 19: "Pigs"
# Song 13: "Phoenix"
# Song 20: "Lotta Years"
# Song 10: "Vomitspit"
# Song 21: "Crows 1"
# Song 16: "Patty Cake"
# Song 14: "Canal St."
# Song 11: "Gazzillion Ear"
# Song 15: "A$AP Forever"
# Song 17: "Pimpin Ain’t Eazy"
# Song 22: "Catacomb Kids"
# Song 12: "?"
# Song 18: "Testimony"
# Song 23: "Big Bang"
# Song 13: "Kon Karne"
# Song 24: "Holy Smokes"
# Song 19: "Versatile"
# Song 25: "Labor"
# Song 20: "Malcolm X.X.X."
# Song 26: "Lazy Eye"
# Song 27: "Rabies"
# Song 16: "Excuse Me"
# Song 21: "G to the A"
# Song 14: "Kookies"
# Song 28: "Klutz"
# Song 22: "Don’t Wanna Breathe"
# Song 29: "Water Tower"
# Song 15: "Kon Queso"
# Song 17: "Brand New Guy"
# Song 23: "Snot Thot"
# Song 30: "TUFF"
# Song 24: "Already"
# Song 18: "Ghetto Symphony"
# Song 25: "Conscience"
# Song 19: "PMW (All I Really Need)"
# Song 26: "If I’m Lyin, I’m Flyin"
# Song 31: "Citronella"
# Song 20: "Purple Swag"
# Song 32: "Supercell"
# Song 16: "Gas Drawls"
# Song 21: "Babushka Boi"
# Song 27: "First Day Out"
# Song 33: "Commencement (at the Obedience Academy)"
# Song 22: "Angels"
# Song 34: "Tetra"
# Song 28: "201519971800"
# Song 35: "Cat Food"
# Song 23: "Electric Body"
# Song 36: "Racing Stripes"
# Song 29: "Everything 1K"
# Song 24: "LVL"
# Song 17: "All Outta Ale"
# Song 37: "Bring Back Pluto"
# Song 18: "Guinnesses"
# Song 30: "Water"
# Song 31: "Young Prodigy"
# Song 32: "Can I"
# Song 38: "Ruby ’81"
# Song 33: "Halloween"
# Song 19: "Batty Boyz"
# Song 39: "Five Fingers"
# Song 20: "My Favorite Ladies"
# Song 25: "Suddenly"
# Song 40: "Battery"
# Song 21: "Tick, Tick..."
# Song 34: "Gave It All I Got"
# Song 26: "Wassup"
# Song 27: "Jukebox Joints"
# Song 41: "Save Yourself"
# Song 22: "Cellz"
# Song 35: "Expeditiously"
# Song 23: "Red & Gold"
# Song 42: "Defender"
# Song 28: "Fukk Sleep"
# Song 43: "The Greatest Pac-Man Victory in History"
# Song 24: "The Finest"
# Song 44: "1,000 O’ Clock"
# Song 45: "Grace"
# Song 25: "Hey!"
# Song 36: "If You Ain’t Ridin’"
# Song 37: "News Or Something (Freestyle)"
# Song 46: "Hot Dogs"
# Song 26: "Dead Bent"
# Song 29: "M’$"
# Song 47: "Molecules"
# Song 38: "Day for Day"
# Song 30: "Purity"
# Song 48: "39 Thieves"
# Song 39: "Slayed"
# Song 49: "Fryerstarter"
# Song 31: "A$AP Forever REMIX"
# Song 50: "One of Four (Thank You)"
# Song 40: "Vibin In This Bih"
# Song 32: "Palace"
# Song 27: "Absolutely"
# Song 41: "Honey Bun"
# Song 42: "6th Sense"
# Song 51: "Homemade Mummy"
# Song 33: "Bass"
# Song 28: "Go with the Flow"
# Song 43: "Signs"
# Song 44: "Could of Been Different"
# Song 34: "Trilla"
# Song 45: "Gnarly"
# Song 29: "Ballskin"
# Song 35: "Holy Ghost"
# Song 36: "Sundress"
# Song 37: "Pretty Flacko"
# Song 46: "Purp"
# Song 38: "Fine Whine"
# Song 30: "Who You Think I Am?"
# Song 39: "Better Things"
# Song 40: "​r - Cali"
# Song 52: "Flashflood"
# Song 41: "Tony Tone"
# Song 47: "Down South"
# Song 42: "Pussy, Money, Weed"
# Song 48: "MoshPit"
# Song 43: "Jodye"
# Song 49: "Unexplainable"
# Song 50: "Coolin and Booted"
# Song 44: "Demons"
# Song 45: "Kissin’ Pink"
# Song 51: "Project Baby"
# Song 31: "Microwave Mayo"
# Song 46: "Keep It G"
# Song 52: "Christmas in Miami"
# Song 53: "Corrlinks and JPay"
# Song 47: "Gunz N Butter"
# Song 54: "From the Cradle"
# Song 53: "Bent Life"
# Song 55: "Take One"
# Song 48: "Hell"
# Song 54: "Saturn Missiles"
# Song 49: "Houston Old Head"
# Song 56: "Fresh Out / My Struggle"
# Song 55: "Keep Off the Lawn"
# Song 56: "The Yes and the Y’all"
# Song 32: "Angelz"
# Song 50: "Get Lit"
# Song 57: "Close to the Grave"
# Song 58: "Need a Break"
# Song 57: "Float"
# Song 33: "More Rhymin’"
# Song 58: "Dokken Rules"
# Song 34: "The M.I.C."
# Timeout raised and caught:
# HTTPSConnectionPool(host='api.genius.com', port=443): Read timed out. (read timeout=5)
# Song 59: "One Brick"
# Song 51: "JD"
# Song 60: "Crows 2"
# Song 52: "Pharsyde"
# Song 61: "Fumes"
# Song 53: "Buck Shots"
# Song 35: "Operation: Greenbacks"
# Song 62: "The Harbor Is Yours"
# Song 54: "Bad Company"
# Song 55: "Purple Kisses"
# Song 63: "Water"
# Song 56: "Leaf (Take 1)"
# Song 64: "No City"
# Song 65: "Fast Cars"
# Song 66: "We’re Famous"
# Song 67: "The Tugboat Complex Pt. 3"
# Song 57: "Out of This World"
# Song 68: "Syrup"
# Song 69: "Drums on the Wheel"
# Song 36: "Lightworks"
# Song 58: "Changes"
# Song 70: "Abandon All Hope"
# Song 59: "I Come Apart"
# Song 37: "Yessir!"
# Song 60: "Purple Swag: Chapter 2"
# Song 71: "Oxygen"
# Song 61: "Max B"
# Song 38: "I Hear Voices Pt.1"
# Song 72: "Gun For the Whole Family"
# Song 62: "Wavybone"
# Song 63: "Pain"
# Song 73: "Coma"
# Song 64: "Kids Turned Out Fine"
# Song 65: "Ridin’"
# Song 74: "Shovel"
# Song 39: "Rap Ambush"
# Song 75: "BMX"
# Song 40: "Poo Putt Platter"
# Song 76: "Garbage"
# Song 77: "I’ll Be OK"
# Song 41: "Fig Leaf Bi-Carbonate"
# Song 66: "Distorted Records"
# Song 78: "Dark Heart News"
# Song 67: "Back Home"
# Song 79: "No Jumper Cables"
# Song 80: "Bazooka Tooth"
# Song 68: "Same Bitch"
# Song 42: "Gumbo"
# Song 69: "Hun43rd"
# Song 70: "New York Bittersweet Symphony"
# Song 81: "Facemelter"
# Song 71: "CALLDROPS"
# Song 82: "Getaway Car"
# Song 83: "Babies with Guns"
# Song 84: "Bug Zapper"
# Song 72: "OG Beeper"
# Song 85: "Zodiaccupuncture"
# Song 43: "Supervillainz"
# Song 86: "1,000 Deaths"
# Song 44: "Fillet-O-Rapper"
# Song 73: "Thuggin’ Noise"
# Song 45: "The Time We Faced Doom"
# Song 87: "The Mayor and the Crook"
# Song 88: "Food, Clothes, Medicine"
# Song 89: "Nickel Plated Pockets"
# Song 46: "Hero vs. Villain (Epilogue)"
# Song 47: "Coco Mango"
# Song 74: "Brotha Man"
# Song 90: "Boombox"
# Song 91: "Basic Cable"
# Song 92: "Alchemy"
# Song 75: "Pretty Flacko (Remix)"
# Song 48: "Still Dope"
# Song 93: "Prosperity"
# Song 94: "The Tugboat Complex"
# Song 76: "BET Cypher 2012: Man With the Iron Fists"
# Song 95: "My Belly"
# Song 77: "M’$ (Single Version)"
# Song 96: "Untouchable (AR Version)"
# Song 49: "Trap Door"
# Song 97: "Cook it Up"
# Song 78: "☆☆☆☆☆ 5IVE $TAR$"
# Song 50: "I Hear Voices"
# Song 79: "West Side Highway"
# Song 98: "Antisocial"
# Song 99: "How to Be a Carpenter"
# Song 100: "Bad Karma"
# Song 101: "11:35"
# Song 102: "Freeze/Honeycomb Interlude"
# Song 103: "No Splash"
# Song 51: "Bells of Doom"
# Song 104: "Shere Khan"
# Song 105: "Rickety Rackety"
# Song 80: "Black Tux, White Collar"
# Song 52: "Hot Guacamole"
# Song 106: "Rogue Wave"
# Song 81: "Roll One Up"
# Song 107: "Bracket Basher"
# Song 82: "Dreams (Interlude)"
# Song 108: "N.Y. Electric"
# Song 83: "A$AP Worldwide Cypher"
# Song 84: "Acid Drip"
# Song 109: "Spare a Match"
# Song 110: "Mars Attacks"
# Song 111: "6B Panorama"
# Song 53: "Back in the Days"
# Song 112: "Maintenance"
# Song 85: "Celebration"
# Song 113: "Skip Town"
# Song 114: "Dryspell"
# "The Impossible Kid Album Art" is not valid. Skipping.
# Song 115: "Attention Span"
# Song 116: "Play Dead"
# Song 117: "KOWP"
# Song 86: "Been Around the World"
# Song 118: "Easy"
# Song 119: "Winners Take All"
# Song 120: "The Substance"
# Song 121: "The Gates"
# Song 122: "Number Nine"
# Song 54: "The Hands of Doom"
# Song 123: "Drawbridge"
# Song 124: "Frijoles"
# Song 125: "Super fluke"
# Song 126: "Fascination"
# Song 127: "Tomorrow Morning"
# Song 87: "Purple Swag REMIX"
# Song 88: "Max Julien"
# Song 89: "Back to the Future"
# Song 90: "Pretty Guy (Snippet)"
# Song 128: "Try Not to Die"
# Song 129: "Thorns"
# Song 130: "Kill the Messenger"
# Song 55: "Hooks is Extra"
# Song 91: "What’s Beef?"
# Song 92: "Funkmaster Flex Freestyle Part 1"
# Song 131: "Hold the Cup"
# Song 56: "Supervillain Intro"
# Song 93: "Get High"
# Song 57: "Impostas"
# Song 94: "Freeze (LNW)"
# Song 95: "Take It Easy Freestyle"
# Song 58: "Doom, Are You Awake?"
# Song 132: "Wake Up Call"
# Song 96: "Grippin’ Woodgrain"
# Song 59: "Is He Ill?"
# Song 60: "Bumpy’s Message"
# Song 133: "Troubled Waters"
# Song 97: "Hear Me"
# Song 98: "In Distress"
# Song 61: "Doomsayer (Young Guru Remix)"
# Song 99: "Quick Ain’t Fair (Adidas Commercial)"
# Song 134: "Same Space (The Tugboat Complex pt. 2)"
# Song 100: "MONEY BAGS FREESTYLE (DEAN BLUNT MEDITATION)"
# Song 135: "Sick Friend"
# Song 136: "The Next Best Thing"
# Song 137: "Odessa"
# Song 138: "Merit"
# "Motivation Foreign (Skit)" is not valid. Skipping.
# Song 139: "Fishtales"
# Song 140: "Blue in the Face"
# Song 101: "Best of Me"
# "The Impossible Kid [Booklet]" is not valid. Skipping.
# Song 102: "Phantogram (Freestyle)"
# Song 141: "Limelighters/Flunkadelic Interlude"
# Song 142: "Bosico"
# Song 103: "Herojuana Blunts"
# Song 104: "Frankenstein"
# Song 62: "Operation: Doomsday Album Covers"
# Song 105: "Uptown"
# Song 63: "Notebook 03"
# Song 143: "Puff Tuff"
# Song 106: "Toast to the Gods"
# Song 64: "Notebook 02 - Doomsayer"
# Song 144: "Plastic Soldiers"
# Song 145: "Wise Up"
# Song 65: "Bookhead"
# Song 146: "Appleseed Intro"
# Song 147: "Black List"
# Song 107: "France Freestyle"
# Song 148: "Coward of the Year"
# Song 108: "Tim Westwood Freestyle"
# Song 109: "Cat Mob"
# Song 149: "Kill ’Em All (Remix)"
# "Long.Live.A$AP [Album Art]" is not valid. Skipping.
# "The Mystery of Doom (Skit)" is not valid. Skipping.
# Song 110: "Wok"
# Song 150: "All Day: Nike+ Original Run"
# Song 111: "Niggas In Paris Freestyle"
# Song 151: "Train Buffer"
# Song 152: "Numb (to the Guns)"
# Song 66: "Thank Ya"
# Song 112: "Tim Westwood TV Freestyle 2013"
# "None Shall Pass Album Art" is not valid. Skipping.
# Song 67: "Lavender Buds"
# Song 113: "Grown Up"
# Song 114: "Above"
# Song 115: "Untitled Snippet (12/19/16)*"
# Song 116: "Sour State of Mind (Light Up Freestyle)"
# Song 153: "89.9FM Nighttrain Promo"
# Song 68: "Coffin Nails"
# Song 154: "Live On 89.9FM Nighttrain"
# Song 117: "Shittin’ Me (Snippet)"
# Song 69: "Arrow Root"
# Song 118: "Who Run It (Freestyle)"
# Song 155: "Coordinates"
# Song 119: "Death Wish"
# Song 70: "Licorice"
# Song 120: "Unicorn"
# Song 156: "Coffee (Main)"
# "Skelethon Album Art" is not valid. Skipping.
# Song 157: "Dead Pan"
# Song 71: "Pennyroyal"
# Song 72: "Hydrochloric Acid"
# Song 158: "Bad Samaritan"
# Song 121: "Public Service Announcement Freestyle"
# Song 122: "Apology to Jason Collins"
# Song 123: "It’s Best for Me to Go*"
# Song 124: "On My Kickz"
# Song 159: "Ace Rocks"
# Song 125: "Issues"
# Song 160: "Forest Crunk"
# Song 73: "Notebook 04"
# Song 161: "Freeze"
# Song 126: "Bamba"
# Song 74: "? (Extended Raw Rhymes Version)"
# Song 127: "Live.Love.A$AP [Mixtape Art]"
# Song 162: "Breakfast With Blockhead"
# Song 163: "The Active Element"
# Song 128: "2 Piece"
# Song 129: "Goldie Mack"
# Song 130: "Feeling Good"
# Song 75: "Gazzillion Ear (Thom Yorke Remix)"
# Song 131: "Blur"
# Song 76: "Mash’s Revenge"
# Song 132: "Don’t Do Drugs"
# "Meet My Crazy Uncle (Skit)" is not valid. Skipping.
# Song 77: "Saffron"
# Song 164: "One Of Four"
# "Labor Days Album Art" is not valid. Skipping.
# Song 165: "Junkyard"
# Song 133: "Babushka Boi (Trailer #1)"
# Song 134: "L$D [Explicit]"
# Song 166: "All In All"
# Song 135: "Perfect Sex"
# Song 136: "Shoot Ur Stylist"
# Song 137: "Lord Pretty Flacko Joyde 3 (LPFJ III)*"
# Song 138: "Millionaire Problems"
# Song 139: "143rd"
# Song 140: "F**kin’ Problems (Clean Version)"
# Song 167: "Lunch with Blockhead"
# Song 141: "Dear My Niggaz"
# Song 142: "Gradually"
# Song 143: "I Really Mean It Goblin/ Yonkers Freestyle"
# Song 144: "FREE ROCKY FREESTYLE"
# Song 145: "Freeze"
# Song 146: "Masquarade"
# Song 147: "(Sittin’ On) The Dock of the Bay"
# Song 168: "11:35 (feat. Mr. Lif) / Ketamine U.S.A. Interlude"
# Song 148: "Everything You Want"
# Song 169: "Dinner With Blockhead"
# "Float Album Art" is not valid. Skipping.
# Song 149: "Crush on You"
# "Bug Zapper (Instrumental)" is not valid. Skipping.
# Song 150: "Cockiness"
# Song 151: "Smeegle"
# Song 152: "Sunshine Goodmorning"
# Song 170: "Shere Kahn"
# "None Shall Pass - Instrumental" is not valid. Skipping.
# Song 153: "Who Next"
# Song 154: "Scarface"
# Song 155: "Heroin*"
# Song 156: "Testing the Kid*"
# Song 78: "Datura Stramonium"
# Song 157: "Awgeshit"
# Song 171: "Rat Skull"
# Song 158: "Jacking for Beats Freestyle"
# Song 159: "Lil Bitch*"
# Song 160: "Run It Up (Snippet)"
# Song 172: "Bold"
# Song 161: "Vibin’ Freestyle"
# Song 173: "Sniff Glue"
# Song 162: "Night School"
# Song 174: "Hall of Game"
# Song 163: "L.A. Leakers Freestyle"
# Song 164: "Who’s Gonna Save My Soul Freestyle"
# Song 165: "Brand New"
# "Fast Cars, Danger, Fire and Knives Album Art" is not valid. Skipping.
# Song 166: "It so Eazy"
# Song 175: "Sink or Swim"
# Song 167: "Been Around the World (Chopped & Screwed)"
# Song 79: "Notebook 06"
# Song 168: "Grow Up: “Get a Job” (Mercedes-Benz Commercial)"
# Song 80: "Lemon Grass"
# Song 169: "Distraction*"
# Song 170: "That Girl"
# Song 171: "Freestylin 101"
# Song 172: "CEO (Freestyle)"
# Song 173: "Hercules*"
# Song 174: "Acid*"
# Song 175: "Drop It"
# Song 81: "Coco Mango (Y Society Power Outage Mix)"
# "Bad Neighbor Tracklist + Album Artwork" is not valid. Skipping.
# Song 176: "Unrelease"
# Song 177: "Power96 Clique Freestyle"
# Song 178: "Savage"
# "The Blob Album Art" is not valid. Skipping.
# Song 179: "AWGE (Intro)"
# Song 180: "Opposition*"
# Song 176: "Hello From The Spirit World"
# Song 181: "Sick Of The Sicka*"
# Song 182: "Nana Castro Cypher 2010"
# Song 183: "Heaven*"
# Song 184: "Flacko Season"
# Song 177: "The Tugboat Complex, Part 3"
# Song 178: "Frozen Caveman"
# Song 82: "The.Green.Whore.Net"
# Song 179: "Jinx Planet"
# Song 185: "Diorboyz"
# Song 186: "Pretty Boy"
# Song 83: "Checkmate"
# "Bazooka Tooth Album Art" is not valid. Skipping.
# Song 187: "On a Cloud*"
# Song 180: "Snowmobile"
# Song 188: "Encore"
# Song 189: "N.W.O"
# Song 84: "Styrax Gum"
# Song 190: "NMC (No More Clones)"
# Song 181: "For The Whole Family"
# Song 191: "Trunk Missing"
# Song 192: "Young & Gettin’ It Freestyle"
# Song 182: "Twice Fried"
# Song 193: "Rave"
# "39 Thieves - Instrumental" is not valid. Skipping.
# Song 194: "You Know It"
# Song 195: "Flipside"
# Song 196: "Globetrotters"
# Song 197: "Mind Your Own Business"
# "NehruvianDOOM Album Art" is not valid. Skipping.
# Song 198: "​srLO*"
# "Cat Food (Instrumental)" is not valid. Skipping.
# "Zero Dark Thirty - Instrumental" is not valid. Skipping.
# "Appleseed Album Art" is not valid. Skipping.
# Song 199: "How to Live"
# Song 183: "Zero Dark Thirty Single Art"
# "Bring Back Pluto - Instrumental" is not valid. Skipping.
# Song 200: "Coast Boys"
# Song 184: "Home Again"
# Song 201: "Forgotten"
# Song 202: "Lenox Avenue"
# "Pigs - instrumental" is not valid. Skipping.
# Song 185: "Gonna Be Limelighters (Oddisee Remix)"
# "All Day: Nike+ Original Run Album Art" is not valid. Skipping.
# Song 203: "Where the Wild Things Are"
# "Be Somebody (Instrumental)" is not valid. Skipping.
# Song 204: "Look"
# "KOWP (Instrumental)" is not valid. Skipping.
# "Gopher Guts - Instrumental" is not valid. Skipping.
# Song 205: "Thank You for Nothing"
# Song 85: "Burdock Root"
# Song 206: "Wizardry Ponder"
# Song 207: "Immodesty"
# Song 208: "Reflex"
# "1,000 O’Clock - Instrumental" is not valid. Skipping.
# Song 209: "Feel and Finesse"
# Song 186: "Horizontal Demo (Instagram 2017)"
# "ZZZ Top - Instrumental" is not valid. Skipping.
# Song 187: "Helium"
# "Coffee - Instrumental" is not valid. Skipping.
# Song 86: "White Willow Bark"
# "Play Dead (Instrumental)" is not valid. Skipping.
# "Drums on the Wheel (Instrumental)" is not valid. Skipping.
# Song 210: "Flacko - Top Mali Freestyle  [S1.E1]  | ProjectNOK"
# Song 188: "Button Masher"
# Song 87: "Hey! (Original 12" Version)"
# Song 189: "Cycles To Gehenna (Zavala Remix)"
# Song 211: "Hola"
# Song 190: "The Blob"
# Song 212: "Smash N Grab"
# "Cycles To Gehenna - Instrumental" is not valid. Skipping.
# "Crows 2 - Instrumental" is not valid. Skipping.
# "Fryerstarter - Instrumental" is not valid. Skipping.
# Song 191: "Corner Store"
# "Catacomb Kids - Instrumental" is not valid. Skipping.
# "Saturn Missiles - Instrumental" is not valid. Skipping.
# Song 88: "Sarsaparilla"
# Song 192: "Salt"
# "Racing Stripes - Instrumental" is not valid. Skipping.
# "Ruby ’81 - Instrumental" is not valid. Skipping.
# "Citronella - Instrumental" is not valid. Skipping.
# "Leisureforce - Instrumental" is not valid. Skipping.
# "Homemade Mummy - Instrumental" is not valid. Skipping.
# "Crows 1 - Instrumental" is not valid. Skipping.
# Song 213: "Dark dog"
# "Innercity Hustle (Instrumental)" is not valid. Skipping.
# Done. Found 213 songs.
# Wrote `Lyrics_AAPRocky.json`
# Song 89: "Charnsuka"
# Song 193: "Mashed Potatoes"
# "Grace - Instrumental" is not valid. Skipping.
# Song 194: "From the very bottom of your tailbone"
# "No City - Instrumental" is not valid. Skipping.
# "The Harbor Is Yours - Instrumental" is not valid. Skipping.
# "Five Fingers - Instrumental" is not valid. Skipping.
# Song 195: "1 To 10"
# "Tetra - Instrumental" is not valid. Skipping.
# "Keep Off The Lawn - Instrumental" is not valid. Skipping.
# Song 196: "Dog at the Door"
# Song 197: "The Church 1"
# Song 198: "All Fall Down"
# Song 199: "Sharks and Minnows"
# Song 200: "Flies"
# "Fumes - Instrumental" is not valid. Skipping.
# Song 201: "Sleeper Car"
# Song 202: "The School"
# Song 90: "Blunt Drunk (All Outta Ale Remix)"
# Song 203: "Fixed and Dilated"
# Song 91: "Benzoin Gum"
# Song 204: "Side Quest"
# Song 205: "Jaguar"
# "Waterlogged (Skit)" is not valid. Skipping.
# Song 206: "Ash"
# Song 207: "The Four Winds"
# Song 92: "One Beer (Madlib Remix)"
# Song 208: "Chesterfield"
# Song 209: "Jumping Coffin"
# Song 210: "Kodokushi"
# Song 211: "Riot Riot"
# Song 212: "Crystal Sword"
# Song 213: "Holy Waterfall"
# Song 214: "Corner Store Reprise"
# Song 215: "The Church 2"
# Song 216: "New Yule"
# Song 93: "Agrimony"
# Song 217: "Coveralls"
# Song 218: "Raiders"
# Song 219: "Ogres"
# Song 94: "Eucalyptus"
# Song 220: "Attaboy"
# Song 221: "New Yule Reprise"
# Song 222: "Downstairs"
# Song 223: "Pizza Alley"
# Song 95: "Mandrake"
# Song 224: "Marble Cake"
# Song 96: "It Ain’t Nuthin’"
# Song 225: "Boot Soup"
# Song 226: "Gauze"
# Done. Found 226 songs.
# Wrote `Lyrics_AesopRock.json`
# Song 97: "Doomsday (Mister Jason Remix)"
# Song 98: "No Snakes Alive (MF EP Version)"
# Song 99: "Zatar"
# Song 100: "Dragon’s Blood"
# Song 101: "Safed Musli"
# Song 102: "Vervain"
# Song 103: "Valerian Root"
# Song 104: "Emblica Officinalis"
# Song 105: "REIGN.. IN THE SUBWAY"
# Song 106: "Monosodium Glutamate"
# Song 107: "Arabic Gum"
# Song 108: "Mighty Healthy / That’s Me (MF DOOM Special Blend)"
# Song 109: "Vinca Rosea"
# Song 110: "Fenugreek"
# Song 111: "Jasmine Blossoms"
# Song 112: "Kava Kava Root"
# Song 113: "Gazzillion Ear (Jneiro Jarel/Dave Sitek Remix)"
# Song 114: "Red #40"
# Song 115: "Elder Blossoms"
# Song 116: "My Favorite Ladies (Latina Remix)"
# Song 117: "Bergamot Wild"
# Song 118: "Mugwort"
# Song 119: "You’re Playing Yourself (MF Doom Special Blend)"
# Song 120: "Camphor"
# Song 121: "Podina"
# Song 122: "Myrrh"
# Song 123: "Orris Root Powder"
# Song 124: "Galangal Root"
# Song 125: "Lovage"
# Song 126: "Vomit"
# Song 127: "Gas Drawls [Demo]"
# Song 128: "Warriorz (MF Doom Special Blend)"
# "Skit 1" is not valid. Skipping.
# Song 129: "Blood Root"
# "Madvillainy Album Art" is not valid. Skipping.
# Song 130: "Coriander"
# Song 131: "Nettle Leaves"
# Song 132: "Gazzillion Ear (Dr. Who Dat? Remix)"
# Song 133: "Apple Tree (MF Doom Special Blend)"
# Song 134: "Calamus"
# Song 135: "Mullein"
# Song 136: "Star Anis"
# Song 137: "Dead Bent (Original 12" Version)"
# Song 138: "Off the Books / Just to Get a Rep (MF Doom Special Blend)"
# "No Snakes Alive (Instrumental)" is not valid. Skipping.
# Song 139: "Chrysanthemum Flowers"
# "Skit 2" is not valid. Skipping.
# Song 140: "Change The Beat (Inhumanz Remix)"
# Song 141: "Buckeyes"
# Song 142: "Devil’s Shoestring"
# Song 143: "Four Thieves Vinegar"
# "Savage Beast (Instrumental)" is not valid. Skipping.
# Song 144: "All Spice"
# Song 145: "Patchouly Leaves"
# Song 146: "Go With The Flow (Original 12" Version)"
# Song 147: "High John"
# Song 148: "Orange Blossoms"
# Song 149: "Sumac Berries"
# Song 150: "Black Snake Root"
# Song 151: "Dragon’s Blood - Resin"
# Song 152: "New Beginning"
# "Fluid (Instrumental)" is not valid. Skipping.
# Song 153: "What a Nigga Know?"
# Song 154: "Fo Ti"
# Song 155: "Calamus Root"
# Song 156: "Shallots"
# Song 157: "Devastator"
# Song 158: "Viktor Vaughn"
# Song 159: "Street Corners (MF Doom Remix)"
# Song 160: "Peach Extract"
# "Popcorn (instrumental)" is not valid. Skipping.
# "Roller Coaster Riders (Instrumental)" is not valid. Skipping.
# "Doomsday (Mister Jason Remix) [Instrumental]" is not valid. Skipping.
# Song 161: "Gazzillion Ear (acapella)"
# Song 162: "Act 1"
# Song 163: "Cedar"
# Song 164: "Coca Leaf"
# Song 165: "Coltsfoot Leaf"
# Song 166: "Hoe Cakes (ANT Remix)"
# Song 167: "Horehound"
# Song 168: "Yellow Dock"
# Song 169: "DOOM talks about the message of the mask"
# Song 170: "Go With the Flow (Live)"
# Song 171: "Smokin’ That Shit!"
# Song 172: "Who Me?"
# Song 173: "Myrtle Leaf"
# Song 174: "All Outta Ale (The Professor Meets The Supervillain)"
# Song 175: "Wormwood"
# Song 176: "Confusion"
# Song 177: "Hyssop"
# Song 178: "Humrush"
# Song 179: "Hoe Cakes (Beatboxappella)"
# Song 180: "Untitled (Meditation)"
# Song 181: "Spikenard"
# Song 182: "Passion Flower"
# "A Personal Score (Skit)" is not valid. Skipping.
# Song 183: "Contact Blitt"
# Song 184: "Garbage Day #3"
# Song 185: "Plumskinzz"
# Song 186: "Intermission"
# Song 187: "Latoya (MF Doom Special Blend)"
# Song 188: "Act 2"
# Song 189: "Kat-Girl-Real-Time"
# Song 190: "Want Not Need"
# Song 191: "It Sounded Like a Roc!"
# Song 192: "Get-U-Now"
# "Doomsday (Instrumental)" is not valid. Skipping.
# Song 193: "Get.the.Feta"
# Song 194: "Constipated Monkey"
# Song 195: "Cinquefoil"
# "Impostas (Instrumental)" is not valid. Skipping.
# Song 196: "Doomed"
# Song 197: "My Favorite Ladies (KMD Remix)"
# Song 198: "Bergamot"
# Song 199: "Meditation"
# Song 200: "Bark"
# Song 201: "Change the Beat"
# "My Love (Instrumental)" is not valid. Skipping.
# "Gazzillion Ear - Instrumental" is not valid. Skipping.
# "Gazzillion Ear- Jneiro Jarel / Dave Sitek Remix / Instrumental" is not valid. Skipping.
# Song 202: "El Umboumbukar"
# "Captain Brunch - Instrumental" is not valid. Skipping.
# "Gazzillion Ear - Thom Yorke Remix / Instrumental" is not valid. Skipping.
# "Gazzillion Ear - Dr. Who Dat? Remix / Instrumental" is not valid. Skipping.
# "Change the Beat (Instrumental Version)" is not valid. Skipping.
# Song 203: "#chessboxin"
# Song 204: "Change the Beat (Acapella Version)"
# Done. Found 204 songs.
# Wrote `Lyrics_MFDOOM.json`
# Searching for songs by kodak black...
#
# Changing artist name to 'Kodak Black'
# Song 1: "Tunnel Vision"
# Song 2: "No Flockin"
# Song 3: "Roll in Peace"
# Song 4: "ZEZE"
# Song 5: "SKRT"
# Song 6: "There He Go"
# Song 7: "Skrilla"
# Song 8: "Codeine Dreaming"
# Song 9: "Transportin’"
# Song 10: "Too Many Years"
# Song 11: "Like Dat"
# Song 12: "Calling My Spirit"
# Song 13: "I.M.Y (I Miss You)"
# Song 14: "Baby Girl"
# Song 15: "Institution"
# Song 16: "Patty Cake"
# Song 17: "Pimpin Ain’t Eazy"
# Song 18: "Testimony"
# Song 19: "Versatile"
# Song 20: "Malcolm X.X.X."
# Song 21: "G to the A"
# Song 22: "Don’t Wanna Breathe"
# Song 23: "Snot Thot"
# Song 24: "Already"
# Song 25: "Conscience"
# Song 26: "If I’m Lyin, I’m Flyin"
# Song 27: "First Day Out"
# Song 28: "201519971800"
# Song 29: "Everything 1K"
# Song 30: "Water"
# Song 31: "Young Prodigy"
# Song 32: "Can I"
# Song 33: "Halloween"
# Song 34: "Gave It All I Got"
# Song 35: "Expeditiously"
# Song 36: "If You Ain’t Ridin’"
# Song 37: "News Or Something (Freestyle)"
# Song 38: "Day for Day"
# Song 39: "Slayed"
# Song 40: "Vibin In This Bih"
# Song 41: "Honey Bun"
# Song 42: "6th Sense"
# Song 43: "Signs"
# Song 44: "Could of Been Different"
# Song 45: "Gnarly"
# Song 46: "Purp"
# Song 47: "Down South"
# Song 48: "MoshPit"
# Song 49: "Unexplainable"
# Song 50: "Coolin and Booted"
# Song 51: "Project Baby"
# Song 52: "Christmas in Miami"
# Song 53: "Corrlinks and JPay"
# Song 54: "From the Cradle"
# Song 55: "Take One"
# Song 56: "Fresh Out / My Struggle"
# Song 57: "Close to the Grave"
# Song 58: "Need a Break"
# Song 59: "Built My Legacy"
# Song 60: "HollyHood"
# Song 61: "Running Outta Love"
# Song 62: "Save You"
# Song 63: "Roll in Peace (Remix)"
# Song 64: "Today"
# Song 65: "Identity Theft"
# Song 66: "No Flockin 2 (Bodak Orange)"
# Song 67: "Heart"
# Song 68: "Dream Doll"
# Song 69: "Free Cool Pt.2"
# Song 70: "Up in Here"
# Song 71: "Reminiscing"
# Song 72: "Side Nigga"
# Song 73: "Fuck With You"
# Song 74: "1800 Nights (Kno The Meaning Freestyle)"
# Song 75: "Deep In These Streets"
# Song 76: "Me, Myself & I"
# Song 77: "Still Hittin Licks"
# Song 78: "Change My Ways"
# Song 79: "Roll N Peace 2"
# Song 80: "Snap Shit"
# Song 81: "Big Bank"
# Song 82: "Cut Throat"
# Song 83: "Because of You"
# Song 84: "XXL Freshman Freestyle: Kodak Black"
# Song 85: "4th Quarter"
# Song 86: "First Love"
# Song 87: "Off the Land"
# Song 88: "When Vultures Cry"
# Song 89: "Loyal"
# Song 90: "Molly"
# Song 91: "U Ain’t Never"
# Song 92: "Misunderstood"
# Song 93: "Bill And Jill"
# Song 94: "Brand New Glizzy"
# Song 95: "I Need Love"
# Song 96: "In Too Deep"
# Song 97: "Fall Thru"
# Song 98: "Top Off Benz"
# Song 99: "Boss My Life Up"
# Song 100: "Erykah Badu"
# Song 101: "Hungry"
# Song 102: "Needing Something"
# Song 103: "I’m That Nigga"
# Song 104: "Shit On Me"
# Song 105: "Spaz Out"
# Song 106: "Acting Weird"
# Song 107: "Time Never Mattered (Seeing Demons) (Do Not Disturb Freestyle)"
# Song 108: "Why You Always Gotta Go"
# Song 109: "Why They Call You Kodak"
# Song 110: "ThankFul"
# Song 111: "Transgression"
# Song 112: "From The Ugly"
# Song 113: "This Forever"
# Song 114: "Me for Me"
# Song 115: "Roll in Peace (Demo)"
# Song 116: "No Meds"
# Song 117: "No CoDefendant"
# Song 118: "Just A Wrap (Freestyle)"
# Song 119: "Versatile 2"
# Song 120: "In the Flesh"
# Song 121: "Gospel"
# Song 122: "Candy Paint"
# Song 123: "Twenty 8"
# Song 124: "Feb 14"
# Song 125: "I N U"
# Song 126: "Real Nigga Files"
# Song 127: "Ambition (I’m 14 And Already Thinking About Death)"
# Song 128: "The Recipe"
# Song 129: "30"
# Song 130: "Poetical G"
# Song 131: "Hate Being Alone"
# Song 132: "Cell Therapy (Freestyle)"
# Song 133: "My Klik"
# Song 134: "No Feelings"
# Song 135: "Boost My Ego"
# Song 136: "Chances"
# Song 137: "Feeling Like"
# Song 138: "Pride"
# Song 139: "Ran Up A Check"
# Song 140: "Free Cool"
# Song 141: "This Life"
# Song 142: "You Do That Shit"
# Song 143: "Get Up"
# Song 144: "Corrupted"
# Song 145: "Real Shit"
# Song 146: "About You Without You"
# Song 147: "I Need A Beat"
# Song 148: "Heart & Mind"
# Song 149: "Honest (Freestyle)"
# Song 150: "Blood Sweat Tears Revenge"
# Song 151: "10 Toes Down"
# Song 152: "Project Baby 2"
# Song 153: "Letter"
# Song 154: "Fed Up"
# Song 155: "Helluva Love"
# Song 156: "Laudy"
# Song 157: "Back On My Feet"
# Song 158: "Kicking In"
# Song 159: "I Get Lonely"
# Song 160: "I Wanna Rock"
# Song 161: "Rock Bottom"
# Song 162: "Heart Of The Projects"
# Song 163: "Up Late"
# Song 164: "I Be On The Way"
# Song 165: "Catch Flight"
# Song 166: "Call You"
# Song 167: "Still in the Streets"
# Song 168: "Believe This Shit"
# Song 169: "Zombie"
# Song 170: "Cognitive"
# Song 171: "Str8 Bars Freestyle"
# Song 172: "Shake Back"
# Song 173: "My Cousin"
# Song 174: "Jewels (Whole Time)"
# Song 175: "Fuck It"
# Song 176: "Now Time"
# Song 177: "Harriet Tubman"
# Song 178: "I Just Might"
# Song 179: "Killing It"
# Song 180: "Love Of My Life"
# Song 181: "Manuvering"
# Song 182: "Yung Niggaz"
# Song 183: "Pelican"
# Song 184: "Black Cat (Kunta Kentae)"
# Song 185: "Mama"
# Song 186: "My Wrist"
# Song 187: "Wake N Bake"
# Song 188: "Shoulda Woulda"
# Song 189: "M.O.H. (Money Over Hoes)"
# Song 190: "Projects"
# Song 191: "Time and a Place"
# Song 192: "Meant For Me"
# Song 193: "18"
# Song 194: "Rugrats"
# Song 195: "1k"
# Song 196: "Here It Is"
# Song 197: "Never Imagine"
# Song 198: "Sticky 1"
# Song 199: "Better Days"
# Song 200: "Take Me Away"
# Song 201: "Again"
# Song 202: "Thug Holiday (Freestyle)"
# Song 203: "Benji’s"
# Song 204: "Off A 14"
# Song 205: "I Remember"
# Song 206: "ProjectBaby Freestyle"
# Song 207: "Crazy"
# Song 208: "Hatin On Me"
# Song 209: "Kill The Beat"
# Song 210: "VULTURES CRY 2"
# Song 211: "Switchin’ Gears"
# Song 212: "Talk About It"
# Song 213: "Ain’t No Fakin’ It"
# Song 214: "Wet"
# Song 215: "Paper Cha$in Haitian"
# Song 216: "Rodeo"
# Song 217: "I’m On"
# Song 218: "Stand Firm"
# Song 219: "5 on it Freestyle"
# Song 220: "Going Viral"
# Song 221: "Get It Up"
# Song 222: "Dead Time"
# Song 223: "Jail House Blues"
# Song 224: "Antisocial"
# Song 225: "Right Now"
# Song 226: "The News"
# Song 227: "Won’t Go Back"
# Song 228: "Luv 2 Flex"
# Song 229: "Conditioned (10 Toes Down Challenge)"
# Song 230: "Destin"
# Song 231: "Broward Paradise"
# Song 232: "I Get The Bag"
# Song 233: "My Time"
# Song 234: "KKK"
# Song 235: "Glow Up"
# Song 236: "Love and War"
# Song 237: "Mystery"
# Song 238: "4th of July"
# Song 239: "Down N Out (Freestyle)"
# Song 240: "Paper Boy"
# Song 241: "10ToesDown Challenge Conditioned"
# Song 242: "Stay Solid"
# Song 243: "Lil Shoota Love"
# Song 244: "Die With You"
# Song 245: "Don’t Understand"
# Song 246: "Too Many Years (Baauer Rewind)"
# Song 247: "KoKo (CoCo Remix)"
# Song 248: "Team No Sleep"
# "Skit" is not valid. Skipping.
# Song 249: "Afterlife"
# Song 250: "Jail Cell Song (I Don’t Know Where I’m Heading)"
# Song 251: "Where Ya At (First Day Out Anthem)"
# Song 252: "I Go"
# Song 253: "Fresh Outta Juvie"
# "Crack Baby Skit" is not valid. Skipping.
# Song 254: "MoshPit (Demo)"
# Song 255: "No Flocking 2"
# Song 256: "Every Time"
# Song 257: "==="
# Song 258: "Need to Blow"
# Song 259: "Sniper"
# Song 260: "Molly Pt. 2"
# Song 261: "Open Letter (Freestyle)"
# Song 262: "Versace (Freestyle)"
# Song 263: "Idk"
# Song 264: "2020"
# Song 265: "Burgerking*"
# Song 266: "XXL Freestyle 2016"
# Song 267: "Testimony Cover"
# Song 268: "Untitled 2"
# Song 269: "Roll In Peace (Extended)"
# Done. Found 269 songs.
# Wrote `Lyrics_KodakBlack.json`

# %% [markdown]
# ### train
#
# then a gpt-2 model gets fine-tuned on the text corpus.

# %%
# from google.colab import files
# files.upload()

# %%
print("training...")
file_name = "lyricdb.txt"
gpt2.download_gpt2(model_name="345M")
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              dataset=file_name,
              model_name='345M',
              steps=steps,
              restore_from='fresh',
              run_name='run1',
              print_every=25,
              sample_every=250,
              save_every=500,
              overwrite=True
              )
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 248Mit/s]
# training...
# Fetching encoder.json: 1.05Mit [00:00, 108Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 175Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:14, 98.4Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 219Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 66.0Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 147Mit/s]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/345M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/345M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:02<00:00,  2.61s/it]
# dataset has 422429 tokens
# Training...
# [25 | 64.72] loss=4.76 avg=4.76
# [50 | 119.89] loss=4.76 avg=4.76
# [75 | 175.34] loss=4.41 avg=4.64
# [100 | 230.99] loss=3.30 avg=4.30
# [125 | 286.61] loss=4.69 avg=4.38
# [150 | 342.33] loss=3.13 avg=4.17
# [175 | 397.96] loss=4.79 avg=4.26
# [200 | 453.61] loss=4.24 avg=4.26
# [225 | 509.29] loss=3.14 avg=4.13
# [250 | 564.97] loss=4.15 avg=4.13
# Saving checkpoint/run1/model-250

# %% [markdown]
# ### generate
#
# then, with this gpt-2 model fine-tuned to rap flavour, rhyming lines in an “aabbaabb…” scheme are generated.

# %%
gen = Generator(sess, log_level="INFO")
lines = gen.generate(line_count)
# Out:
# INFO:root:generating lines...
# 100% (3 of 3) |##########################| Elapsed Time: 0:02:55 Time:  0:02:55
# INFO:root:generating lines... done!
# I'm looking forward to popping by again and bringing back hot
# While I'm at it, I should mention I finally got
# Daredevil has been a part of the Marvel comic book pant
# I hate to abuse your patience, but I just can't

# %% [markdown]
# ## pretty print

# %%
# !pip install art
# Out:
# Collecting art
#   Downloading https://files.pythonhosted.org/packages/22/dd/f7be08119239db50f80285444323e58c81d6443158ac5f8b401b3fedb4d0/art-4.7-py2.py3-none-any.whl (547kB)
#      |████████████████████████████████| 552kB 3.4MB/s
# Installing collected packages: art
# Successfully installed art-4.7

# %%
from art import *

# %%
for line in lines:
    print(line)
# Out:
# I'm looking forward to popping by again and bringing back hot
# While I'm at it, I should mention I finally got
# Daredevil has been a part of the Marvel comic book pant
# I hate to abuse your patience, but I just can't

# %%
for line in lines:
    print(text2art(line, font="small"))
# Out:
#  ___  _          _            _    _                __                                  _   _                                 _               _                              _                        _   _          _              _               _               _     _          _
# |_ _|( ) _ __   | | ___  ___ | |__(_) _ _   __ _   / _| ___  _ _ __ __ __ __ _  _ _  __| | | |_  ___   _ __  ___  _ __  _ __ (_) _ _   __ _  | |__  _  _   __ _  __ _  __ _ (_) _ _    __ _  _ _   __| | | |__  _ _ (_) _ _   __ _ (_) _ _   __ _  | |__  __ _  __ | |__ | |_   ___ | |_
#  | | |/ | '  \  | |/ _ \/ _ \| / /| || ' \ / _` | |  _|/ _ \| '_|\ V  V // _` || '_|/ _` | |  _|/ _ \ | '_ \/ _ \| '_ \| '_ \| || ' \ / _` | | '_ \| || | / _` |/ _` |/ _` || || ' \  / _` || ' \ / _` | | '_ \| '_|| || ' \ / _` || || ' \ / _` | | '_ \/ _` |/ _|| / / | ' \ / _ \|  _|
# |___|   |_|_|_| |_|\___/\___/|_\_\|_||_||_|\__, | |_|  \___/|_|   \_/\_/ \__,_||_|  \__,_|  \__|\___/ | .__/\___/| .__/| .__/|_||_||_|\__, | |_.__/ \_, | \__,_|\__, |\__,_||_||_||_| \__,_||_||_|\__,_| |_.__/|_|  |_||_||_|\__, ||_||_||_|\__, | |_.__/\__,_|\__||_\_\ |_||_|\___/ \__|
#                                            |___/                                                      |_|        |_|   |_|            |___/         |__/        |___/                                                        |___/          |___/
#
# __      __ _     _  _        ___  _                _     _  _        ___       _                _     _                     _    _              ___    __  _              _  _                    _
# \ \    / /| |_  (_)| | ___  |_ _|( ) _ __    __ _ | |_  (_)| |_     |_ _|  ___| |_   ___  _  _ | | __| |  _ __   ___  _ _  | |_ (_) ___  _ _   |_ _|  / _|(_) _ _   __ _ | || | _  _   __ _  ___ | |_
#  \ \/\/ / | ' \ | || |/ -_)  | | |/ | '  \  / _` ||  _| | ||  _| _   | |  (_-<| ' \ / _ \| || || |/ _` | | '  \ / -_)| ' \ |  _|| |/ _ \| ' \   | |  |  _|| || ' \ / _` || || || || | / _` |/ _ \|  _|
#   \_/\_/  |_||_||_||_|\___| |___|   |_|_|_| \__,_| \__| |_| \__|( ) |___| /__/|_||_|\___/ \_,_||_|\__,_| |_|_|_|\___||_||_| \__||_|\___/|_||_| |___| |_|  |_||_||_|\__,_||_||_| \_, | \__, |\___/ \__|
#                                                                 |/                                                                                                              |__/  |___/
#
#  ___                      _            _  _   _                _                                              _           __   _    _           __  __                       _                   _       _               _                       _
# |   \  __ _  _ _  ___  __| | ___ __ __(_)| | | |_   __ _  ___ | |__  ___  ___  _ _    __ _   _ __  __ _  _ _ | |_   ___  / _| | |_ | |_   ___  |  \/  | __ _  _ _ __ __ ___ | |  __  ___  _ __  (_) __  | |__  ___  ___ | |__  _ __  __ _  _ _  | |_
# | |) |/ _` || '_|/ -_)/ _` |/ -_)\ V /| || | | ' \ / _` |(_-< | '_ \/ -_)/ -_)| ' \  / _` | | '_ \/ _` || '_||  _| / _ \|  _| |  _|| ' \ / -_) | |\/| |/ _` || '_|\ V // -_)| | / _|/ _ \| '  \ | |/ _| | '_ \/ _ \/ _ \| / / | '_ \/ _` || ' \ |  _|
# |___/ \__,_||_|  \___|\__,_|\___| \_/ |_||_| |_||_|\__,_|/__/ |_.__/\___|\___||_||_| \__,_| | .__/\__,_||_|   \__| \___/|_|    \__||_||_|\___| |_|  |_|\__,_||_|   \_/ \___||_| \__|\___/|_|_|_||_|\__| |_.__/\___/\___/|_\_\ | .__/\__,_||_||_| \__|
#                                                                                             |_|                                                                                                                               |_|
#
#  ___   _           _          _                _                                                        _    _                          _           _     ___     _            _                     _  _
# |_ _| | |_   __ _ | |_  ___  | |_  ___   __ _ | |__  _  _  ___ ___   _  _  ___  _  _  _ _   _ __  __ _ | |_ (_) ___  _ _   __  ___     | |__  _  _ | |_  |_ _|   (_) _  _  ___| |_   __  __ _  _ _  ( )| |_
#  | |  | ' \ / _` ||  _|/ -_) |  _|/ _ \ / _` || '_ \| || |(_-</ -_) | || |/ _ \| || || '_| | '_ \/ _` ||  _|| |/ -_)| ' \ / _|/ -_) _  | '_ \| || ||  _|  | |    | || || |(_-<|  _| / _|/ _` || ' \ |/ |  _|
# |___| |_||_|\__,_| \__|\___|  \__|\___/ \__,_||_.__/ \_,_|/__/\___|  \_, |\___/ \_,_||_|   | .__/\__,_| \__||_|\___||_||_|\__|\___|( ) |_.__/ \_,_| \__| |___|  _/ | \_,_|/__/ \__| \__|\__,_||_||_|    \__|
#                                                                      |__/                  |_|                                     |/                          |__/

# %% [markdown]
# ## outro

# %% [markdown]
# ### author: [pelgo14](https://github.com/pelgo14)
# read my [blog post](https://pelgo14.github.io/artificial-rapper) for more information
#
#
# ### reference: [Max Woolf](http://minimaxir.com) says
# For more about `gpt-2-simple`, you can visit [this GitHub repository](https://github.com/minimaxir/gpt-2-simple). You can also read my [blog post](https://minimaxir.com/2019/09/howto-gpt2/) for more information how to use this notebook!
#
# ### original paper
# https://openai.com/blog/better-language-models/
